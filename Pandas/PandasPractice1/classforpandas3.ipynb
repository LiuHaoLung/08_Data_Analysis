# %%
import pandas

# %%
url = 'https://en.wikipedia.org/wiki/Python_(programming_language)'

# %%
d = pandas.read_html(url)

# %%
d
# Out:
# [                                                    0  \
#  0                                                 NaN
#  1                                            Paradigm
#  2                                         Designed by
#  3                                           Developer
#  4                                      First appeared
#  5                                                 NaN
#  6                                      Stable release
#  7                                     Preview release
#  8                                   Typing discipline
#  9                                             License
#  10                                Filename extensions
#  11                                            Website
#  12                              Major implementations
#  13  CPython, PyPy, Stackless Python, MicroPython, ...
#  14                                           Dialects
#  15                       Cython, RPython, Starlark[8]
# ...

# %%
d = pandas.read_html(url)[1]

# %%
d
# Out:
#                    Type Mutability  \
# 0                  bool  immutable
# 1             bytearray    mutable
# 2                 bytes  immutable
# 3               complex  immutable
# 4                  dict    mutable
# 5             ellipsisa  immutable
# 6                 float  immutable
# 7             frozenset  immutable
# 8                   int  immutable
# 9                  list    mutable
# 10            NoneTypea  immutable
# 11  NotImplementedTypea  immutable
# 12                  set    mutable
# 13                  str  immutable
# 14                tuple  immutable
#
#                                           Description  \
# 0                                       Boolean value
# 1                                   Sequence of bytes
# 2                                   Sequence of bytes
# 3        Complex number with real and imaginary parts
# 4   Associative array (or dictionary) of key and v...
# 5   An ellipsis placeholder to be used as an index...
# ...

# %% [markdown]
# 這個表格在這個網頁裡面，是第二個，所以要抓 index 1。
