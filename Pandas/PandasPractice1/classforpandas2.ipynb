# %%
import pandas

# %%
dtxt = pandas.read_csv('/Users/How.Short/Desktop/Employees.txt')

# %%
dtxt
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dtxt2 = pandas.read_csv('/Users/How.Short/Desktop/Employees2.txt',delimiter = '|')

# %%
dtxt2
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9      Test     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %% [markdown]
# 可以指定要分割的分隔符號，用 delimiter = '' 就可以指定分隔符號。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv')

# %%
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv',header = None)

# %%
dcsv
# Out:
#      0          1         2           3           4                    5  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          6                7
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %% [markdown]
# 可以把最上面的行給去掉，用 Header = None，就會把原本最上面的行，當成表格的第一行，且 column 就會變成數字。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv',header = None,names = ['A','B','C','D','E','F','G','H'])

# %%
dcsv
# Out:
#      A          B         C           D           E                    F  \
# 0   ID  FirstName  LastName  Department       Phone              Address
# 1    1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2    2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3    3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4    4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5    5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6    6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7    7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8    8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9    9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10  10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#          G                H
# 0   Salary           Skills
# 1    52000     Online Sales
# ...

# %% [markdown]
# 除了可以去掉，也可以用 names = []，重新指定 column，在 list 裡面打上相對應數量的 column 就可以取代數字。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv',header = None,prefix = 'COL')

# %%
dcsv
# Out:
#    COL0       COL1      COL2        COL3        COL4                 COL5  \
# 0    ID  FirstName  LastName  Department       Phone              Address
# 1     1       Luke   Phillip       Sales  1234567890   1st Address, Miami
# 2     2       Jack    Darren          IT  1234567891   2nd Address, Miami
# 3     3        Ken      Wood          IT  1234567892   3rd Address, Miami
# 4     4       John    Wilson   Marketing  1234567893   4th Address, Miami
# 5     5      Emily    Larson   Marketing  1234567894   5th Address, Miami
# 6     6       Anna  Sullivan       Sales  1234567895   6th Address, Miami
# 7     7    Richard     Smith   Logistics  1234567896   7th Address, Miami
# 8     8     Ronnie     Moore       Sales  1234567897   8th Address, Miami
# 9     9        Ron     Drake          IT  1234567898   9th Address, Miami
# 10   10      Wayne    Barker   Logistics  1234567899  10th Address, Miami
#
#       COL6             COL7
# 0   Salary           Skills
# ...

# %% [markdown]
# 可以用 prefix 的方式，定義一個字串，執行後就會在每個 column 上加上這個字串，並有數字。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv')

# %%
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index('ID')
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.set_index('ID',inplace = True)
dcsv
# Out:
#    FirstName  LastName Department       Phone              Address  Salary  \
# ID
# 1       Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 2       Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 3        Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 4       John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5      Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 6       Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 7    Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 8     Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 9        Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#              Skills
# ID
# 1      Online Sales
# 2        Networking
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# ...

# %% [markdown]
# 利用 set_index('',inplace = True) 的方法，就可以把原本的 index(0-9)去掉，並用在 '' 裡的數字，當作新的 index。

# %%
dcsv.set_index('Address',inplace = True)
dcsv
# Out:
#                     FirstName  LastName Department       Phone  Salary  \
# Address
# 1st Address, Miami       Luke   Phillip      Sales  1234567890   52000
# 2nd Address, Miami       Jack    Darren         IT  1234567891   52200
# 3rd Address, Miami        Ken      Wood         IT  1234567892   58000
# 4th Address, Miami       John    Wilson  Marketing  1234567893   58700
# 5th Address, Miami      Emily    Larson  Marketing  1234567894   60000
# 6th Address, Miami       Anna  Sullivan      Sales  1234567895   54000
# 7th Address, Miami    Richard     Smith  Logistics  1234567896   56000
# 8th Address, Miami     Ronnie     Moore      Sales  1234567897   49000
# 9th Address, Miami        Ron     Drake         IT  1234567898   53000
# 10th Address, Miami     Wayne    Barker  Logistics  1234567899   59500
#
#                               Skills
# Address
# 1st Address, Miami      Online Sales
# 2nd Address, Miami        Networking
# 3rd Address, Miami      Python, Java
# ...

# %% [markdown]
# 也就是說可以利用不同的欄位，利用 set_index 的方式，將不同的欄位設為 index。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv')

# %%
dcsv
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dcsv.shape
# Out:
# (10, 8)

# %% [markdown]
# 可以用 .shape 來看這個檔案有幾欄幾列。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv',skiprows = 4)

# %%
dcsv
# Out:
#     4     John    Wilson  Marketing  1234567893   4th Address, Miami  58700  \
# 0   5    Emily    Larson  Marketing  1234567894   5th Address, Miami  60000
# 1   6     Anna  Sullivan      Sales  1234567895   6th Address, Miami  54000
# 2   7  Richard     Smith  Logistics  1234567896   7th Address, Miami  56000
# 3   8   Ronnie     Moore      Sales  1234567897   8th Address, Miami  49000
# 4   9      Ron     Drake         IT  1234567898   9th Address, Miami  53000
# 5  10    Wayne    Barker  Logistics  1234567899  10th Address, Miami  59500
#
#       Facebook Ads
# 0    Instagram Ads
# 1  In-Person Sales
# 2  Warehouse Mgmt.
# 3     Online Sales
# 4    Linux Servers
# 5  Product Loading

# %% [markdown]
# 可以用 skiprows 來忽略不想輸入的行，所以當 skiprows = 4 就代表前四行都會被忽略掉。

# %%
dcsv = pandas.read_csv('/Users/How.Short/Desktop/Employees.csv',nrows = 5)

# %%
dcsv
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 0   1      Luke  Phillip      Sales  1234567890  1st Address, Miami   52000
# 1   2      Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 2   3       Ken     Wood         IT  1234567892  3rd Address, Miami   58000
# 3   4      John   Wilson  Marketing  1234567893  4th Address, Miami   58700
# 4   5     Emily   Larson  Marketing  1234567894  5th Address, Miami   60000
#
#           Skills
# 0   Online Sales
# 1     Networking
# 2   Python, Java
# 3   Facebook Ads
# 4  Instagram Ads

# %% [markdown]
# 如果用 nrows 則代表是在這個數字前的都會被顯示出來，所以當 nrows = 5 ，則代表 1到5行都會顯示。

# %%
djson = pandas.read_json('/Users/How.Short/Desktop/Employees.json')

# %%
djson
# Out:
#                Address Department FirstName  ID  LastName       Phone  Salary  \
# 0   1st Address, Miami      Sales      Luke   1   Phillip  1234567890   52000
# 1   2nd Address, Miami         IT      Jack   2    Darren  1234567891   52200
# 2   3rd Address, Miami         IT       Ken   3      Wood  1234567892   58000
# 3   4th Address, Miami  Marketing      John   4    Wilson  1234567893   58700
# 4   5th Address, Miami  Marketing     Emily   5    Larson  1234567894   60000
# 5   6th Address, Miami      Sales      Anna   6  Sullivan  1234567895   54000
# 6   7th Address, Miami  Logistics   Richard   7     Smith  1234567896   56000
# 7   8th Address, Miami      Sales    Ronnie   8     Moore  1234567897   49000
# 8   9th Address, Miami         IT       Ron   9     Drake  1234567898   53000
# 9  10th Address, Miami  Logistics     Wayne  10    Barker  1234567899   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dxlsx = pandas.read_excel('/Users/How.Short/Desktop/Employees.xlsx')

# %%
dxlsx
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %%
dxlsx = pandas.read_excel('/Users/How.Short/Desktop/Employees.xlsx',sheet_name = 0)

# %%
dxlsx
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# ...

# %% [markdown]
# 可以指定要顯示出的活頁簿，sheet_name = 0 就是第一個活頁簿。
